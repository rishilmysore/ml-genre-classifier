# %% [markdown]
# **Music Genre Classification using CNN**

# %%
# Arrays
import numpy as np

# Everything audio file related
import librosa, librosa.display

# Visualization
import matplotlib.pyplot as plt

# For file management
import os

# ceil() function
import math

# %%
# Function for splitting dataset
from sklearn.model_selection import train_test_split

import tensorflow.keras as keras

import tensorflow as tf

from tensorflow.keras import datasets, layers, models

# %%
from keras.models import Sequential  
from keras.layers import Dense, Dropout, Activation, Flatten 
from keras.layers import Convolution2D, MaxPooling2D 
from keras.utils import np_utils

# %%
# GTZAN Dataset located in Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Step 1: Create MFCC files from the audio files.**

# %% [markdown]
# Variables related to audio files and MFCC parameters.

# %%
dataPath = "/content/drive/MyDrive/genres_original"
sampleRate = 22050 # (Hz)
trackLength = 30 # (second)
numMFCC = 20    # Number of MFCC for each audio file segment.
nFFT = 2048     # Length of the FFT window
hopLength = 512 # Number of samples between each frame.
segments = 13   # Number of segments for dividing audio file.
samplePerSeg = int(661500 / segments)
mfccPerSeg = math.ceil(samplePerSeg / hopLength)

# %% [markdown]
# We save and load the MFCC files in a numpy array for further processing.

# %%
# Dict for converting non-numeric feature into a numeric feature.
genreToNum = {
      "blues":0,
      "classical":1,
      "country":2,
      "disco":3,
      "hiphop":4,
      "jazz" :5,
      "metal" :6,
      "pop" :7,
      "reggae" :8,
      "rock" :9
  }

# Initialize output variables
XasList = []
y = np.array([]);

# Go through genre files
for subdir, dirs, files in os.walk(dataPath):

      # Go through audio files
      for file in files:

          # Get the genre name from current folder.
          currentGenre = subdir.split("/")[-1]
          currentGenreNum = genreToNum[currentGenre]
          
          # Load audio file using librosa.
          currentFile = os.path.join(subdir, file)
          currentAudio,sampleRate = librosa.load(currentFile, sr=sampleRate)
          
          # Go through one audio file
          for i in range(segments):

            # Print which audio file is currently being worked on.
            printMessage = f'Working on: {currentFile.split("/")[6]} Segment {i}'
            print(printMessage)

            # Calculate the start and finish points of segments.
            start = samplePerSeg * i
            finish = start + samplePerSeg

            # Calculate mfcc of audio segment.
            mfcc = librosa.feature.mfcc(currentAudio[start:finish], sampleRate, n_mfcc=numMFCC, n_fft=nFFT, hop_length=hopLength)
            mfcc = mfcc.T

            # Add MFCC to data only if the mfcc vector length are good
            
            if mfcc.shape[0] == mfccPerSeg:
              XasList.append(mfcc.tolist())
              y = np.append(y,currentGenreNum)
# Convert python list to numpy array
X = np.array(XasList)
# Out:
# Streaming output truncated to the last 5000 lines.
# Working on: pop.00011.wav Segment 5
# Working on: pop.00011.wav Segment 6
# Working on: pop.00011.wav Segment 7
# Working on: pop.00011.wav Segment 8
# Working on: pop.00011.wav Segment 9
# Working on: pop.00011.wav Segment 10
# Working on: pop.00011.wav Segment 11
# Working on: pop.00011.wav Segment 12
# Working on: pop.00016.wav Segment 0
# Working on: pop.00016.wav Segment 1
# Working on: pop.00016.wav Segment 2
# Working on: pop.00016.wav Segment 3
# Working on: pop.00016.wav Segment 4
# Working on: pop.00016.wav Segment 5
# Working on: pop.00016.wav Segment 6
# Working on: pop.00016.wav Segment 7
# Working on: pop.00016.wav Segment 8
# Working on: pop.00016.wav Segment 9
# Working on: pop.00016.wav Segment 10
# Working on: pop.00016.wav Segment 11
# Working on: pop.00016.wav Segment 12
# Working on: pop.00008.wav Segment 0
# Working on: pop.00008.wav Segment 1
# Working on: pop.00008.wav Segment 2
# Working on: pop.00008.wav Segment 3
# Working on: pop.00008.wav Segment 4
# Working on: pop.00008.wav Segment 5
# Working on: pop.00008.wav Segment 6
# Working on: pop.00008.wav Segment 7
# Working on: pop.00008.wav Segment 8
# Working on: pop.00008.wav Segment 9
# Working on: pop.00008.wav Segment 10
# Working on: pop.00008.wav Segment 11
# Working on: pop.00008.wav Segment 12
# Working on: pop.00019.wav Segment 0
# Working on: pop.00019.wav Segment 1
# Working on: pop.00019.wav Segment 2
# Working on: pop.00019.wav Segment 3
# Working on: pop.00019.wav Segment 4
# Working on: pop.00019.wav Segment 5
# Working on: pop.00019.wav Segment 6
# Working on: pop.00019.wav Segment 7
# Working on: pop.00019.wav Segment 8
# Working on: pop.00019.wav Segment 9
# Working on: pop.00019.wav Segment 10
# Working on: pop.00019.wav Segment 11
# Working on: pop.00019.wav Segment 12
# Working on: pop.00013.wav Segment 0
# Working on: pop.00013.wav Segment 1
# Working on: pop.00013.wav Segment 2
# Working on: pop.00013.wav Segment 3
# Working on: pop.00013.wav Segment 4
# Working on: pop.00013.wav Segment 5
# Working on: pop.00013.wav Segment 6
# Working on: pop.00013.wav Segment 7
# Working on: pop.00013.wav Segment 8
# Working on: pop.00013.wav Segment 9
# Working on: pop.00013.wav Segment 10
# Working on: pop.00013.wav Segment 11
# Working on: pop.00013.wav Segment 12
# Working on: pop.00024.wav Segment 0
# Working on: pop.00024.wav Segment 1
# Working on: pop.00024.wav Segment 2
# Working on: pop.00024.wav Segment 3
# Working on: pop.00024.wav Segment 4
# Working on: pop.00024.wav Segment 5
# Working on: pop.00024.wav Segment 6
# Working on: pop.00024.wav Segment 7
# Working on: pop.00024.wav Segment 8
# Working on: pop.00024.wav Segment 9
# Working on: pop.00024.wav Segment 10
# Working on: pop.00024.wav Segment 11
# Working on: pop.00024.wav Segment 12
# Working on: pop.00026.wav Segment 0
# Working on: pop.00026.wav Segment 1
# Working on: pop.00026.wav Segment 2
# Working on: pop.00026.wav Segment 3
# Working on: pop.00026.wav Segment 4
# Working on: pop.00026.wav Segment 5
# Working on: pop.00026.wav Segment 6
# Working on: pop.00026.wav Segment 7
# Working on: pop.00026.wav Segment 8
# Working on: pop.00026.wav Segment 9
# Working on: pop.00026.wav Segment 10
# Working on: pop.00026.wav Segment 11
# Working on: pop.00026.wav Segment 12
# Working on: pop.00028.wav Segment 0
# Working on: pop.00028.wav Segment 1
# Working on: pop.00028.wav Segment 2
# Working on: pop.00028.wav Segment 3
# Working on: pop.00028.wav Segment 4
# Working on: pop.00028.wav Segment 5
# Working on: pop.00028.wav Segment 6
# Working on: pop.00028.wav Segment 7
# Working on: pop.00028.wav Segment 8
# Working on: pop.00028.wav Segment 9
# Working on: pop.00028.wav Segment 10
# Working on: pop.00028.wav Segment 11
# Working on: pop.00028.wav Segment 12
# Working on: pop.00029.wav Segment 0
# Working on: pop.00029.wav Segment 1
# Working on: pop.00029.wav Segment 2
# Working on: pop.00029.wav Segment 3
# Working on: pop.00029.wav Segment 4
# Working on: pop.00029.wav Segment 5
# Working on: pop.00029.wav Segment 6
# Working on: pop.00029.wav Segment 7
# Working on: pop.00029.wav Segment 8
# Working on: pop.00029.wav Segment 9
# Working on: pop.00029.wav Segment 10
# Working on: pop.00029.wav Segment 11
# Working on: pop.00029.wav Segment 12
# Working on: pop.00032.wav Segment 0
# Working on: pop.00032.wav Segment 1
# Working on: pop.00032.wav Segment 2
# Working on: pop.00032.wav Segment 3
# Working on: pop.00032.wav Segment 4
# Working on: pop.00032.wav Segment 5
# Working on: pop.00032.wav Segment 6
# Working on: pop.00032.wav Segment 7
# Working on: pop.00032.wav Segment 8
# Working on: pop.00032.wav Segment 9
# Working on: pop.00032.wav Segment 10
# Working on: pop.00032.wav Segment 11
# Working on: pop.00032.wav Segment 12
# Working on: pop.00030.wav Segment 0
# Working on: pop.00030.wav Segment 1
# Working on: pop.00030.wav Segment 2
# Working on: pop.00030.wav Segment 3
# Working on: pop.00030.wav Segment 4
# Working on: pop.00030.wav Segment 5
# Working on: pop.00030.wav Segment 6
# Working on: pop.00030.wav Segment 7
# Working on: pop.00030.wav Segment 8
# Working on: pop.00030.wav Segment 9
# Working on: pop.00030.wav Segment 10
# Working on: pop.00030.wav Segment 11
# Working on: pop.00030.wav Segment 12
# Working on: pop.00020.wav Segment 0
# Working on: pop.00020.wav Segment 1
# Working on: pop.00020.wav Segment 2
# Working on: pop.00020.wav Segment 3
# Working on: pop.00020.wav Segment 4
# Working on: pop.00020.wav Segment 5
# Working on: pop.00020.wav Segment 6
# Working on: pop.00020.wav Segment 7
# Working on: pop.00020.wav Segment 8
# Working on: pop.00020.wav Segment 9
# Working on: pop.00020.wav Segment 10
# Working on: pop.00020.wav Segment 11
# Working on: pop.00020.wav Segment 12
# Working on: pop.00021.wav Segment 0
# Working on: pop.00021.wav Segment 1
# Working on: pop.00021.wav Segment 2
# Working on: pop.00021.wav Segment 3
# Working on: pop.00021.wav Segment 4
# Working on: pop.00021.wav Segment 5
# Working on: pop.00021.wav Segment 6
# Working on: pop.00021.wav Segment 7
# Working on: pop.00021.wav Segment 8
# Working on: pop.00021.wav Segment 9
# Working on: pop.00021.wav Segment 10
# Working on: pop.00021.wav Segment 11
# Working on: pop.00021.wav Segment 12
# Working on: pop.00022.wav Segment 0
# Working on: pop.00022.wav Segment 1
# Working on: pop.00022.wav Segment 2
# Working on: pop.00022.wav Segment 3
# Working on: pop.00022.wav Segment 4
# Working on: pop.00022.wav Segment 5
# Working on: pop.00022.wav Segment 6
# Working on: pop.00022.wav Segment 7
# Working on: pop.00022.wav Segment 8
# Working on: pop.00022.wav Segment 9
# Working on: pop.00022.wav Segment 10
# Working on: pop.00022.wav Segment 11
# Working on: pop.00022.wav Segment 12
# Working on: pop.00033.wav Segment 0
# Working on: pop.00033.wav Segment 1
# Working on: pop.00033.wav Segment 2
# Working on: pop.00033.wav Segment 3
# Working on: pop.00033.wav Segment 4
# Working on: pop.00033.wav Segment 5
# Working on: pop.00033.wav Segment 6
# Working on: pop.00033.wav Segment 7
# Working on: pop.00033.wav Segment 8
# Working on: pop.00033.wav Segment 9
# Working on: pop.00033.wav Segment 10
# Working on: pop.00033.wav Segment 11
# Working on: pop.00033.wav Segment 12
# Working on: pop.00027.wav Segment 0
# Working on: pop.00027.wav Segment 1
# Working on: pop.00027.wav Segment 2
# Working on: pop.00027.wav Segment 3
# Working on: pop.00027.wav Segment 4
# Working on: pop.00027.wav Segment 5
# Working on: pop.00027.wav Segment 6
# Working on: pop.00027.wav Segment 7
# Working on: pop.00027.wav Segment 8
# Working on: pop.00027.wav Segment 9
# Working on: pop.00027.wav Segment 10
# Working on: pop.00027.wav Segment 11
# Working on: pop.00027.wav Segment 12
# Working on: pop.00023.wav Segment 0
# Working on: pop.00023.wav Segment 1
# Working on: pop.00023.wav Segment 2
# Working on: pop.00023.wav Segment 3
# Working on: pop.00023.wav Segment 4
# Working on: pop.00023.wav Segment 5
# Working on: pop.00023.wav Segment 6
# Working on: pop.00023.wav Segment 7
# Working on: pop.00023.wav Segment 8
# Working on: pop.00023.wav Segment 9
# Working on: pop.00023.wav Segment 10
# Working on: pop.00023.wav Segment 11
# Working on: pop.00023.wav Segment 12
# Working on: pop.00031.wav Segment 0
# Working on: pop.00031.wav Segment 1
# Working on: pop.00031.wav Segment 2
# Working on: pop.00031.wav Segment 3
# Working on: pop.00031.wav Segment 4
# Working on: pop.00031.wav Segment 5
# Working on: pop.00031.wav Segment 6
# Working on: pop.00031.wav Segment 7
# Working on: pop.00031.wav Segment 8
# Working on: pop.00031.wav Segment 9
# Working on: pop.00031.wav Segment 10
# Working on: pop.00031.wav Segment 11
# Working on: pop.00031.wav Segment 12
# Working on: pop.00025.wav Segment 0
# Working on: pop.00025.wav Segment 1
# Working on: pop.00025.wav Segment 2
# Working on: pop.00025.wav Segment 3
# Working on: pop.00025.wav Segment 4
# Working on: pop.00025.wav Segment 5
# Working on: pop.00025.wav Segment 6
# Working on: pop.00025.wav Segment 7
# Working on: pop.00025.wav Segment 8
# Working on: pop.00025.wav Segment 9
# Working on: pop.00025.wav Segment 10
# Working on: pop.00025.wav Segment 11
# Working on: pop.00025.wav Segment 12
# Working on: pop.00034.wav Segment 0
# Working on: pop.00034.wav Segment 1
# Working on: pop.00034.wav Segment 2
# Working on: pop.00034.wav Segment 3
# Working on: pop.00034.wav Segment 4
# Working on: pop.00034.wav Segment 5
# Working on: pop.00034.wav Segment 6
# Working on: pop.00034.wav Segment 7
# Working on: pop.00034.wav Segment 8
# Working on: pop.00034.wav Segment 9
# Working on: pop.00034.wav Segment 10
# Working on: pop.00034.wav Segment 11
# Working on: pop.00034.wav Segment 12
# Working on: pop.00041.wav Segment 0
# Working on: pop.00041.wav Segment 1
# Working on: pop.00041.wav Segment 2
# Working on: pop.00041.wav Segment 3
# Working on: pop.00041.wav Segment 4
# Working on: pop.00041.wav Segment 5
# Working on: pop.00041.wav Segment 6
# Working on: pop.00041.wav Segment 7
# Working on: pop.00041.wav Segment 8
# Working on: pop.00041.wav Segment 9
# Working on: pop.00041.wav Segment 10
# Working on: pop.00041.wav Segment 11
# Working on: pop.00041.wav Segment 12
# Working on: pop.00044.wav Segment 0
# Working on: pop.00044.wav Segment 1
# Working on: pop.00044.wav Segment 2
# Working on: pop.00044.wav Segment 3
# Working on: pop.00044.wav Segment 4
# Working on: pop.00044.wav Segment 5
# Working on: pop.00044.wav Segment 6
# Working on: pop.00044.wav Segment 7
# Working on: pop.00044.wav Segment 8
# Working on: pop.00044.wav Segment 9
# Working on: pop.00044.wav Segment 10
# Working on: pop.00044.wav Segment 11
# Working on: pop.00044.wav Segment 12
# Working on: pop.00036.wav Segment 0
# Working on: pop.00036.wav Segment 1
# Working on: pop.00036.wav Segment 2
# Working on: pop.00036.wav Segment 3
# Working on: pop.00036.wav Segment 4
# Working on: pop.00036.wav Segment 5
# Working on: pop.00036.wav Segment 6
# Working on: pop.00036.wav Segment 7
# Working on: pop.00036.wav Segment 8
# Working on: pop.00036.wav Segment 9
# Working on: pop.00036.wav Segment 10
# Working on: pop.00036.wav Segment 11
# Working on: pop.00036.wav Segment 12
# Working on: pop.00045.wav Segment 0
# Working on: pop.00045.wav Segment 1
# Working on: pop.00045.wav Segment 2
# Working on: pop.00045.wav Segment 3
# Working on: pop.00045.wav Segment 4
# Working on: pop.00045.wav Segment 5
# Working on: pop.00045.wav Segment 6
# Working on: pop.00045.wav Segment 7
# Working on: pop.00045.wav Segment 8
# Working on: pop.00045.wav Segment 9
# Working on: pop.00045.wav Segment 10
# Working on: pop.00045.wav Segment 11
# Working on: pop.00045.wav Segment 12
# Working on: pop.00042.wav Segment 0
# Working on: pop.00042.wav Segment 1
# Working on: pop.00042.wav Segment 2
# Working on: pop.00042.wav Segment 3
# Working on: pop.00042.wav Segment 4
# Working on: pop.00042.wav Segment 5
# Working on: pop.00042.wav Segment 6
# Working on: pop.00042.wav Segment 7
# Working on: pop.00042.wav Segment 8
# Working on: pop.00042.wav Segment 9
# Working on: pop.00042.wav Segment 10
# Working on: pop.00042.wav Segment 11
# Working on: pop.00042.wav Segment 12
# Working on: pop.00040.wav Segment 0
# Working on: pop.00040.wav Segment 1
# Working on: pop.00040.wav Segment 2
# Working on: pop.00040.wav Segment 3
# Working on: pop.00040.wav Segment 4
# Working on: pop.00040.wav Segment 5
# Working on: pop.00040.wav Segment 6
# Working on: pop.00040.wav Segment 7
# Working on: pop.00040.wav Segment 8
# Working on: pop.00040.wav Segment 9
# Working on: pop.00040.wav Segment 10
# Working on: pop.00040.wav Segment 11
# Working on: pop.00040.wav Segment 12
# Working on: pop.00048.wav Segment 0
# Working on: pop.00048.wav Segment 1
# Working on: pop.00048.wav Segment 2
# Working on: pop.00048.wav Segment 3
# Working on: pop.00048.wav Segment 4
# Working on: pop.00048.wav Segment 5
# Working on: pop.00048.wav Segment 6
# Working on: pop.00048.wav Segment 7
# Working on: pop.00048.wav Segment 8
# Working on: pop.00048.wav Segment 9
# Working on: pop.00048.wav Segment 10
# Working on: pop.00048.wav Segment 11
# Working on: pop.00048.wav Segment 12
# Working on: pop.00043.wav Segment 0
# Working on: pop.00043.wav Segment 1
# Working on: pop.00043.wav Segment 2
# Working on: pop.00043.wav Segment 3
# Working on: pop.00043.wav Segment 4
# Working on: pop.00043.wav Segment 5
# Working on: pop.00043.wav Segment 6
# Working on: pop.00043.wav Segment 7
# Working on: pop.00043.wav Segment 8
# Working on: pop.00043.wav Segment 9
# Working on: pop.00043.wav Segment 10
# Working on: pop.00043.wav Segment 11
# Working on: pop.00043.wav Segment 12
# Working on: pop.00037.wav Segment 0
# Working on: pop.00037.wav Segment 1
# Working on: pop.00037.wav Segment 2
# Working on: pop.00037.wav Segment 3
# Working on: pop.00037.wav Segment 4
# Working on: pop.00037.wav Segment 5
# Working on: pop.00037.wav Segment 6
# Working on: pop.00037.wav Segment 7
# Working on: pop.00037.wav Segment 8
# Working on: pop.00037.wav Segment 9
# Working on: pop.00037.wav Segment 10
# Working on: pop.00037.wav Segment 11
# Working on: pop.00037.wav Segment 12
# Working on: pop.00038.wav Segment 0
# Working on: pop.00038.wav Segment 1
# Working on: pop.00038.wav Segment 2
# Working on: pop.00038.wav Segment 3
# Working on: pop.00038.wav Segment 4
# Working on: pop.00038.wav Segment 5
# Working on: pop.00038.wav Segment 6
# Working on: pop.00038.wav Segment 7
# Working on: pop.00038.wav Segment 8
# Working on: pop.00038.wav Segment 9
# Working on: pop.00038.wav Segment 10
# Working on: pop.00038.wav Segment 11
# Working on: pop.00038.wav Segment 12
# Working on: pop.00046.wav Segment 0
# Working on: pop.00046.wav Segment 1
# Working on: pop.00046.wav Segment 2
# Working on: pop.00046.wav Segment 3
# Working on: pop.00046.wav Segment 4
# Working on: pop.00046.wav Segment 5
# Working on: pop.00046.wav Segment 6
# Working on: pop.00046.wav Segment 7
# Working on: pop.00046.wav Segment 8
# Working on: pop.00046.wav Segment 9
# Working on: pop.00046.wav Segment 10
# Working on: pop.00046.wav Segment 11
# Working on: pop.00046.wav Segment 12
# Working on: pop.00039.wav Segment 0
# Working on: pop.00039.wav Segment 1
# Working on: pop.00039.wav Segment 2
# Working on: pop.00039.wav Segment 3
# Working on: pop.00039.wav Segment 4
# Working on: pop.00039.wav Segment 5
# Working on: pop.00039.wav Segment 6
# Working on: pop.00039.wav Segment 7
# Working on: pop.00039.wav Segment 8
# Working on: pop.00039.wav Segment 9
# Working on: pop.00039.wav Segment 10
# Working on: pop.00039.wav Segment 11
# Working on: pop.00039.wav Segment 12
# Working on: pop.00047.wav Segment 0
# Working on: pop.00047.wav Segment 1
# Working on: pop.00047.wav Segment 2
# Working on: pop.00047.wav Segment 3
# Working on: pop.00047.wav Segment 4
# Working on: pop.00047.wav Segment 5
# Working on: pop.00047.wav Segment 6
# Working on: pop.00047.wav Segment 7
# Working on: pop.00047.wav Segment 8
# Working on: pop.00047.wav Segment 9
# Working on: pop.00047.wav Segment 10
# Working on: pop.00047.wav Segment 11
# Working on: pop.00047.wav Segment 12
# Working on: pop.00035.wav Segment 0
# Working on: pop.00035.wav Segment 1
# Working on: pop.00035.wav Segment 2
# Working on: pop.00035.wav Segment 3
# Working on: pop.00035.wav Segment 4
# Working on: pop.00035.wav Segment 5
# Working on: pop.00035.wav Segment 6
# Working on: pop.00035.wav Segment 7
# Working on: pop.00035.wav Segment 8
# Working on: pop.00035.wav Segment 9
# Working on: pop.00035.wav Segment 10
# Working on: pop.00035.wav Segment 11
# Working on: pop.00035.wav Segment 12
# Working on: pop.00056.wav Segment 0
# Working on: pop.00056.wav Segment 1
# Working on: pop.00056.wav Segment 2
# Working on: pop.00056.wav Segment 3
# Working on: pop.00056.wav Segment 4
# Working on: pop.00056.wav Segment 5
# Working on: pop.00056.wav Segment 6
# Working on: pop.00056.wav Segment 7
# Working on: pop.00056.wav Segment 8
# Working on: pop.00056.wav Segment 9
# Working on: pop.00056.wav Segment 10
# Working on: pop.00056.wav Segment 11
# Working on: pop.00056.wav Segment 12
# Working on: pop.00061.wav Segment 0
# Working on: pop.00061.wav Segment 1
# Working on: pop.00061.wav Segment 2
# Working on: pop.00061.wav Segment 3
# Working on: pop.00061.wav Segment 4
# Working on: pop.00061.wav Segment 5
# Working on: pop.00061.wav Segment 6
# Working on: pop.00061.wav Segment 7
# Working on: pop.00061.wav Segment 8
# Working on: pop.00061.wav Segment 9
# Working on: pop.00061.wav Segment 10
# Working on: pop.00061.wav Segment 11
# Working on: pop.00061.wav Segment 12
# Working on: pop.00057.wav Segment 0
# Working on: pop.00057.wav Segment 1
# Working on: pop.00057.wav Segment 2
# Working on: pop.00057.wav Segment 3
# Working on: pop.00057.wav Segment 4
# Working on: pop.00057.wav Segment 5
# Working on: pop.00057.wav Segment 6
# Working on: pop.00057.wav Segment 7
# Working on: pop.00057.wav Segment 8
# Working on: pop.00057.wav Segment 9
# Working on: pop.00057.wav Segment 10
# Working on: pop.00057.wav Segment 11
# Working on: pop.00057.wav Segment 12
# Working on: pop.00054.wav Segment 0
# Working on: pop.00054.wav Segment 1
# Working on: pop.00054.wav Segment 2
# Working on: pop.00054.wav Segment 3
# Working on: pop.00054.wav Segment 4
# Working on: pop.00054.wav Segment 5
# Working on: pop.00054.wav Segment 6
# Working on: pop.00054.wav Segment 7
# Working on: pop.00054.wav Segment 8
# Working on: pop.00054.wav Segment 9
# Working on: pop.00054.wav Segment 10
# Working on: pop.00054.wav Segment 11
# Working on: pop.00054.wav Segment 12
# Working on: pop.00058.wav Segment 0
# Working on: pop.00058.wav Segment 1
# Working on: pop.00058.wav Segment 2
# Working on: pop.00058.wav Segment 3
# Working on: pop.00058.wav Segment 4
# Working on: pop.00058.wav Segment 5
# Working on: pop.00058.wav Segment 6
# Working on: pop.00058.wav Segment 7
# Working on: pop.00058.wav Segment 8
# Working on: pop.00058.wav Segment 9
# Working on: pop.00058.wav Segment 10
# Working on: pop.00058.wav Segment 11
# Working on: pop.00058.wav Segment 12
# Working on: pop.00055.wav Segment 0
# Working on: pop.00055.wav Segment 1
# Working on: pop.00055.wav Segment 2
# Working on: pop.00055.wav Segment 3
# Working on: pop.00055.wav Segment 4
# Working on: pop.00055.wav Segment 5
# Working on: pop.00055.wav Segment 6
# Working on: pop.00055.wav Segment 7
# Working on: pop.00055.wav Segment 8
# Working on: pop.00055.wav Segment 9
# Working on: pop.00055.wav Segment 10
# Working on: pop.00055.wav Segment 11
# Working on: pop.00055.wav Segment 12
# Working on: pop.00049.wav Segment 0
# Working on: pop.00049.wav Segment 1
# Working on: pop.00049.wav Segment 2
# Working on: pop.00049.wav Segment 3
# Working on: pop.00049.wav Segment 4
# Working on: pop.00049.wav Segment 5
# Working on: pop.00049.wav Segment 6
# Working on: pop.00049.wav Segment 7
# Working on: pop.00049.wav Segment 8
# Working on: pop.00049.wav Segment 9
# Working on: pop.00049.wav Segment 10
# Working on: pop.00049.wav Segment 11
# Working on: pop.00049.wav Segment 12
# Working on: pop.00050.wav Segment 0
# Working on: pop.00050.wav Segment 1
# Working on: pop.00050.wav Segment 2
# Working on: pop.00050.wav Segment 3
# Working on: pop.00050.wav Segment 4
# Working on: pop.00050.wav Segment 5
# Working on: pop.00050.wav Segment 6
# Working on: pop.00050.wav Segment 7
# Working on: pop.00050.wav Segment 8
# Working on: pop.00050.wav Segment 9
# Working on: pop.00050.wav Segment 10
# Working on: pop.00050.wav Segment 11
# Working on: pop.00050.wav Segment 12
# Working on: pop.00059.wav Segment 0
# Working on: pop.00059.wav Segment 1
# Working on: pop.00059.wav Segment 2
# Working on: pop.00059.wav Segment 3
# Working on: pop.00059.wav Segment 4
# Working on: pop.00059.wav Segment 5
# Working on: pop.00059.wav Segment 6
# Working on: pop.00059.wav Segment 7
# Working on: pop.00059.wav Segment 8
# Working on: pop.00059.wav Segment 9
# Working on: pop.00059.wav Segment 10
# Working on: pop.00059.wav Segment 11
# Working on: pop.00059.wav Segment 12
# Working on: pop.00060.wav Segment 0
# Working on: pop.00060.wav Segment 1
# Working on: pop.00060.wav Segment 2
# Working on: pop.00060.wav Segment 3
# Working on: pop.00060.wav Segment 4
# Working on: pop.00060.wav Segment 5
# Working on: pop.00060.wav Segment 6
# Working on: pop.00060.wav Segment 7
# Working on: pop.00060.wav Segment 8
# Working on: pop.00060.wav Segment 9
# Working on: pop.00060.wav Segment 10
# Working on: pop.00060.wav Segment 11
# Working on: pop.00060.wav Segment 12
# Working on: pop.00052.wav Segment 0
# Working on: pop.00052.wav Segment 1
# Working on: pop.00052.wav Segment 2
# Working on: pop.00052.wav Segment 3
# Working on: pop.00052.wav Segment 4
# Working on: pop.00052.wav Segment 5
# Working on: pop.00052.wav Segment 6
# Working on: pop.00052.wav Segment 7
# Working on: pop.00052.wav Segment 8
# Working on: pop.00052.wav Segment 9
# Working on: pop.00052.wav Segment 10
# Working on: pop.00052.wav Segment 11
# Working on: pop.00052.wav Segment 12
# Working on: pop.00062.wav Segment 0
# Working on: pop.00062.wav Segment 1
# Working on: pop.00062.wav Segment 2
# Working on: pop.00062.wav Segment 3
# Working on: pop.00062.wav Segment 4
# Working on: pop.00062.wav Segment 5
# Working on: pop.00062.wav Segment 6
# Working on: pop.00062.wav Segment 7
# Working on: pop.00062.wav Segment 8
# Working on: pop.00062.wav Segment 9
# Working on: pop.00062.wav Segment 10
# Working on: pop.00062.wav Segment 11
# Working on: pop.00062.wav Segment 12
# Working on: pop.00051.wav Segment 0
# Working on: pop.00051.wav Segment 1
# Working on: pop.00051.wav Segment 2
# Working on: pop.00051.wav Segment 3
# Working on: pop.00051.wav Segment 4
# Working on: pop.00051.wav Segment 5
# Working on: pop.00051.wav Segment 6
# Working on: pop.00051.wav Segment 7
# Working on: pop.00051.wav Segment 8
# Working on: pop.00051.wav Segment 9
# Working on: pop.00051.wav Segment 10
# Working on: pop.00051.wav Segment 11
# Working on: pop.00051.wav Segment 12
# Working on: pop.00053.wav Segment 0
# Working on: pop.00053.wav Segment 1
# Working on: pop.00053.wav Segment 2
# Working on: pop.00053.wav Segment 3
# Working on: pop.00053.wav Segment 4
# Working on: pop.00053.wav Segment 5
# Working on: pop.00053.wav Segment 6
# Working on: pop.00053.wav Segment 7
# Working on: pop.00053.wav Segment 8
# Working on: pop.00053.wav Segment 9
# Working on: pop.00053.wav Segment 10
# Working on: pop.00053.wav Segment 11
# Working on: pop.00053.wav Segment 12
# Working on: pop.00066.wav Segment 0
# Working on: pop.00066.wav Segment 1
# Working on: pop.00066.wav Segment 2
# Working on: pop.00066.wav Segment 3
# Working on: pop.00066.wav Segment 4
# Working on: pop.00066.wav Segment 5
# Working on: pop.00066.wav Segment 6
# Working on: pop.00066.wav Segment 7
# Working on: pop.00066.wav Segment 8
# Working on: pop.00066.wav Segment 9
# Working on: pop.00066.wav Segment 10
# Working on: pop.00066.wav Segment 11
# Working on: pop.00066.wav Segment 12
# Working on: pop.00071.wav Segment 0
# Working on: pop.00071.wav Segment 1
# Working on: pop.00071.wav Segment 2
# Working on: pop.00071.wav Segment 3
# Working on: pop.00071.wav Segment 4
# Working on: pop.00071.wav Segment 5
# Working on: pop.00071.wav Segment 6
# Working on: pop.00071.wav Segment 7
# Working on: pop.00071.wav Segment 8
# Working on: pop.00071.wav Segment 9
# Working on: pop.00071.wav Segment 10
# Working on: pop.00071.wav Segment 11
# Working on: pop.00071.wav Segment 12
# Working on: pop.00064.wav Segment 0
# Working on: pop.00064.wav Segment 1
# Working on: pop.00064.wav Segment 2
# Working on: pop.00064.wav Segment 3
# Working on: pop.00064.wav Segment 4
# Working on: pop.00064.wav Segment 5
# Working on: pop.00064.wav Segment 6
# Working on: pop.00064.wav Segment 7
# Working on: pop.00064.wav Segment 8
# Working on: pop.00064.wav Segment 9
# Working on: pop.00064.wav Segment 10
# Working on: pop.00064.wav Segment 11
# Working on: pop.00064.wav Segment 12
# Working on: pop.00073.wav Segment 0
# Working on: pop.00073.wav Segment 1
# Working on: pop.00073.wav Segment 2
# Working on: pop.00073.wav Segment 3
# Working on: pop.00073.wav Segment 4
# Working on: pop.00073.wav Segment 5
# Working on: pop.00073.wav Segment 6
# Working on: pop.00073.wav Segment 7
# Working on: pop.00073.wav Segment 8
# Working on: pop.00073.wav Segment 9
# Working on: pop.00073.wav Segment 10
# Working on: pop.00073.wav Segment 11
# Working on: pop.00073.wav Segment 12
# Working on: pop.00069.wav Segment 0
# Working on: pop.00069.wav Segment 1
# Working on: pop.00069.wav Segment 2
# Working on: pop.00069.wav Segment 3
# Working on: pop.00069.wav Segment 4
# Working on: pop.00069.wav Segment 5
# Working on: pop.00069.wav Segment 6
# Working on: pop.00069.wav Segment 7
# Working on: pop.00069.wav Segment 8
# Working on: pop.00069.wav Segment 9
# Working on: pop.00069.wav Segment 10
# Working on: pop.00069.wav Segment 11
# Working on: pop.00069.wav Segment 12
# Working on: pop.00076.wav Segment 0
# Working on: pop.00076.wav Segment 1
# Working on: pop.00076.wav Segment 2
# Working on: pop.00076.wav Segment 3
# Working on: pop.00076.wav Segment 4
# Working on: pop.00076.wav Segment 5
# Working on: pop.00076.wav Segment 6
# Working on: pop.00076.wav Segment 7
# Working on: pop.00076.wav Segment 8
# Working on: pop.00076.wav Segment 9
# Working on: pop.00076.wav Segment 10
# Working on: pop.00076.wav Segment 11
# Working on: pop.00076.wav Segment 12
# Working on: pop.00074.wav Segment 0
# Working on: pop.00074.wav Segment 1
# Working on: pop.00074.wav Segment 2
# Working on: pop.00074.wav Segment 3
# Working on: pop.00074.wav Segment 4
# Working on: pop.00074.wav Segment 5
# Working on: pop.00074.wav Segment 6
# Working on: pop.00074.wav Segment 7
# Working on: pop.00074.wav Segment 8
# Working on: pop.00074.wav Segment 9
# Working on: pop.00074.wav Segment 10
# Working on: pop.00074.wav Segment 11
# Working on: pop.00074.wav Segment 12
# Working on: pop.00065.wav Segment 0
# Working on: pop.00065.wav Segment 1
# Working on: pop.00065.wav Segment 2
# Working on: pop.00065.wav Segment 3
# Working on: pop.00065.wav Segment 4
# Working on: pop.00065.wav Segment 5
# Working on: pop.00065.wav Segment 6
# Working on: pop.00065.wav Segment 7
# Working on: pop.00065.wav Segment 8
# Working on: pop.00065.wav Segment 9
# Working on: pop.00065.wav Segment 10
# Working on: pop.00065.wav Segment 11
# Working on: pop.00065.wav Segment 12
# Working on: pop.00075.wav Segment 0
# Working on: pop.00075.wav Segment 1
# Working on: pop.00075.wav Segment 2
# Working on: pop.00075.wav Segment 3
# Working on: pop.00075.wav Segment 4
# Working on: pop.00075.wav Segment 5
# Working on: pop.00075.wav Segment 6
# Working on: pop.00075.wav Segment 7
# Working on: pop.00075.wav Segment 8
# Working on: pop.00075.wav Segment 9
# Working on: pop.00075.wav Segment 10
# Working on: pop.00075.wav Segment 11
# Working on: pop.00075.wav Segment 12
# Working on: pop.00070.wav Segment 0
# Working on: pop.00070.wav Segment 1
# Working on: pop.00070.wav Segment 2
# Working on: pop.00070.wav Segment 3
# Working on: pop.00070.wav Segment 4
# Working on: pop.00070.wav Segment 5
# Working on: pop.00070.wav Segment 6
# Working on: pop.00070.wav Segment 7
# Working on: pop.00070.wav Segment 8
# Working on: pop.00070.wav Segment 9
# Working on: pop.00070.wav Segment 10
# Working on: pop.00070.wav Segment 11
# Working on: pop.00070.wav Segment 12
# Working on: pop.00067.wav Segment 0
# Working on: pop.00067.wav Segment 1
# Working on: pop.00067.wav Segment 2
# Working on: pop.00067.wav Segment 3
# Working on: pop.00067.wav Segment 4
# Working on: pop.00067.wav Segment 5
# Working on: pop.00067.wav Segment 6
# Working on: pop.00067.wav Segment 7
# Working on: pop.00067.wav Segment 8
# Working on: pop.00067.wav Segment 9
# Working on: pop.00067.wav Segment 10
# Working on: pop.00067.wav Segment 11
# Working on: pop.00067.wav Segment 12
# Working on: pop.00068.wav Segment 0
# Working on: pop.00068.wav Segment 1
# Working on: pop.00068.wav Segment 2
# Working on: pop.00068.wav Segment 3
# Working on: pop.00068.wav Segment 4
# Working on: pop.00068.wav Segment 5
# Working on: pop.00068.wav Segment 6
# Working on: pop.00068.wav Segment 7
# Working on: pop.00068.wav Segment 8
# Working on: pop.00068.wav Segment 9
# Working on: pop.00068.wav Segment 10
# Working on: pop.00068.wav Segment 11
# Working on: pop.00068.wav Segment 12
# Working on: pop.00072.wav Segment 0
# Working on: pop.00072.wav Segment 1
# Working on: pop.00072.wav Segment 2
# Working on: pop.00072.wav Segment 3
# Working on: pop.00072.wav Segment 4
# Working on: pop.00072.wav Segment 5
# Working on: pop.00072.wav Segment 6
# Working on: pop.00072.wav Segment 7
# Working on: pop.00072.wav Segment 8
# Working on: pop.00072.wav Segment 9
# Working on: pop.00072.wav Segment 10
# Working on: pop.00072.wav Segment 11
# Working on: pop.00072.wav Segment 12
# Working on: pop.00063.wav Segment 0
# Working on: pop.00063.wav Segment 1
# Working on: pop.00063.wav Segment 2
# Working on: pop.00063.wav Segment 3
# Working on: pop.00063.wav Segment 4
# Working on: pop.00063.wav Segment 5
# Working on: pop.00063.wav Segment 6
# Working on: pop.00063.wav Segment 7
# Working on: pop.00063.wav Segment 8
# Working on: pop.00063.wav Segment 9
# Working on: pop.00063.wav Segment 10
# Working on: pop.00063.wav Segment 11
# Working on: pop.00063.wav Segment 12
# Working on: pop.00079.wav Segment 0
# Working on: pop.00079.wav Segment 1
# Working on: pop.00079.wav Segment 2
# Working on: pop.00079.wav Segment 3
# Working on: pop.00079.wav Segment 4
# Working on: pop.00079.wav Segment 5
# Working on: pop.00079.wav Segment 6
# Working on: pop.00079.wav Segment 7
# Working on: pop.00079.wav Segment 8
# Working on: pop.00079.wav Segment 9
# Working on: pop.00079.wav Segment 10
# Working on: pop.00079.wav Segment 11
# Working on: pop.00079.wav Segment 12
# Working on: pop.00077.wav Segment 0
# Working on: pop.00077.wav Segment 1
# Working on: pop.00077.wav Segment 2
# Working on: pop.00077.wav Segment 3
# Working on: pop.00077.wav Segment 4
# Working on: pop.00077.wav Segment 5
# Working on: pop.00077.wav Segment 6
# Working on: pop.00077.wav Segment 7
# Working on: pop.00077.wav Segment 8
# Working on: pop.00077.wav Segment 9
# Working on: pop.00077.wav Segment 10
# Working on: pop.00077.wav Segment 11
# Working on: pop.00077.wav Segment 12
# Working on: pop.00085.wav Segment 0
# Working on: pop.00085.wav Segment 1
# Working on: pop.00085.wav Segment 2
# Working on: pop.00085.wav Segment 3
# Working on: pop.00085.wav Segment 4
# Working on: pop.00085.wav Segment 5
# Working on: pop.00085.wav Segment 6
# Working on: pop.00085.wav Segment 7
# Working on: pop.00085.wav Segment 8
# Working on: pop.00085.wav Segment 9
# Working on: pop.00085.wav Segment 10
# Working on: pop.00085.wav Segment 11
# Working on: pop.00085.wav Segment 12
# Working on: pop.00084.wav Segment 0
# Working on: pop.00084.wav Segment 1
# Working on: pop.00084.wav Segment 2
# Working on: pop.00084.wav Segment 3
# Working on: pop.00084.wav Segment 4
# Working on: pop.00084.wav Segment 5
# Working on: pop.00084.wav Segment 6
# Working on: pop.00084.wav Segment 7
# Working on: pop.00084.wav Segment 8
# Working on: pop.00084.wav Segment 9
# Working on: pop.00084.wav Segment 10
# Working on: pop.00084.wav Segment 11
# Working on: pop.00084.wav Segment 12
# Working on: pop.00089.wav Segment 0
# Working on: pop.00089.wav Segment 1
# Working on: pop.00089.wav Segment 2
# Working on: pop.00089.wav Segment 3
# Working on: pop.00089.wav Segment 4
# Working on: pop.00089.wav Segment 5
# Working on: pop.00089.wav Segment 6
# Working on: pop.00089.wav Segment 7
# Working on: pop.00089.wav Segment 8
# Working on: pop.00089.wav Segment 9
# Working on: pop.00089.wav Segment 10
# Working on: pop.00089.wav Segment 11
# Working on: pop.00089.wav Segment 12
# Working on: pop.00087.wav Segment 0
# Working on: pop.00087.wav Segment 1
# Working on: pop.00087.wav Segment 2
# Working on: pop.00087.wav Segment 3
# Working on: pop.00087.wav Segment 4
# Working on: pop.00087.wav Segment 5
# Working on: pop.00087.wav Segment 6
# Working on: pop.00087.wav Segment 7
# Working on: pop.00087.wav Segment 8
# Working on: pop.00087.wav Segment 9
# Working on: pop.00087.wav Segment 10
# Working on: pop.00087.wav Segment 11
# Working on: pop.00087.wav Segment 12
# Working on: pop.00080.wav Segment 0
# Working on: pop.00080.wav Segment 1
# Working on: pop.00080.wav Segment 2
# Working on: pop.00080.wav Segment 3
# Working on: pop.00080.wav Segment 4
# Working on: pop.00080.wav Segment 5
# Working on: pop.00080.wav Segment 6
# Working on: pop.00080.wav Segment 7
# Working on: pop.00080.wav Segment 8
# Working on: pop.00080.wav Segment 9
# Working on: pop.00080.wav Segment 10
# Working on: pop.00080.wav Segment 11
# Working on: pop.00080.wav Segment 12
# Working on: pop.00088.wav Segment 0
# Working on: pop.00088.wav Segment 1
# Working on: pop.00088.wav Segment 2
# Working on: pop.00088.wav Segment 3
# Working on: pop.00088.wav Segment 4
# Working on: pop.00088.wav Segment 5
# Working on: pop.00088.wav Segment 6
# Working on: pop.00088.wav Segment 7
# Working on: pop.00088.wav Segment 8
# Working on: pop.00088.wav Segment 9
# Working on: pop.00088.wav Segment 10
# Working on: pop.00088.wav Segment 11
# Working on: pop.00088.wav Segment 12
# Working on: pop.00078.wav Segment 0
# Working on: pop.00078.wav Segment 1
# Working on: pop.00078.wav Segment 2
# Working on: pop.00078.wav Segment 3
# Working on: pop.00078.wav Segment 4
# Working on: pop.00078.wav Segment 5
# Working on: pop.00078.wav Segment 6
# Working on: pop.00078.wav Segment 7
# Working on: pop.00078.wav Segment 8
# Working on: pop.00078.wav Segment 9
# Working on: pop.00078.wav Segment 10
# Working on: pop.00078.wav Segment 11
# Working on: pop.00078.wav Segment 12
# Working on: pop.00082.wav Segment 0
# Working on: pop.00082.wav Segment 1
# Working on: pop.00082.wav Segment 2
# Working on: pop.00082.wav Segment 3
# Working on: pop.00082.wav Segment 4
# Working on: pop.00082.wav Segment 5
# Working on: pop.00082.wav Segment 6
# Working on: pop.00082.wav Segment 7
# Working on: pop.00082.wav Segment 8
# Working on: pop.00082.wav Segment 9
# Working on: pop.00082.wav Segment 10
# Working on: pop.00082.wav Segment 11
# Working on: pop.00082.wav Segment 12
# Working on: pop.00081.wav Segment 0
# Working on: pop.00081.wav Segment 1
# Working on: pop.00081.wav Segment 2
# Working on: pop.00081.wav Segment 3
# Working on: pop.00081.wav Segment 4
# Working on: pop.00081.wav Segment 5
# Working on: pop.00081.wav Segment 6
# Working on: pop.00081.wav Segment 7
# Working on: pop.00081.wav Segment 8
# Working on: pop.00081.wav Segment 9
# Working on: pop.00081.wav Segment 10
# Working on: pop.00081.wav Segment 11
# Working on: pop.00081.wav Segment 12
# Working on: pop.00086.wav Segment 0
# Working on: pop.00086.wav Segment 1
# Working on: pop.00086.wav Segment 2
# Working on: pop.00086.wav Segment 3
# Working on: pop.00086.wav Segment 4
# Working on: pop.00086.wav Segment 5
# Working on: pop.00086.wav Segment 6
# Working on: pop.00086.wav Segment 7
# Working on: pop.00086.wav Segment 8
# Working on: pop.00086.wav Segment 9
# Working on: pop.00086.wav Segment 10
# Working on: pop.00086.wav Segment 11
# Working on: pop.00086.wav Segment 12
# Working on: pop.00083.wav Segment 0
# Working on: pop.00083.wav Segment 1
# Working on: pop.00083.wav Segment 2
# Working on: pop.00083.wav Segment 3
# Working on: pop.00083.wav Segment 4
# Working on: pop.00083.wav Segment 5
# Working on: pop.00083.wav Segment 6
# Working on: pop.00083.wav Segment 7
# Working on: pop.00083.wav Segment 8
# Working on: pop.00083.wav Segment 9
# Working on: pop.00083.wav Segment 10
# Working on: pop.00083.wav Segment 11
# Working on: pop.00083.wav Segment 12
# Working on: pop.00092.wav Segment 0
# Working on: pop.00092.wav Segment 1
# Working on: pop.00092.wav Segment 2
# Working on: pop.00092.wav Segment 3
# Working on: pop.00092.wav Segment 4
# Working on: pop.00092.wav Segment 5
# Working on: pop.00092.wav Segment 6
# Working on: pop.00092.wav Segment 7
# Working on: pop.00092.wav Segment 8
# Working on: pop.00092.wav Segment 9
# Working on: pop.00092.wav Segment 10
# Working on: pop.00092.wav Segment 11
# Working on: pop.00092.wav Segment 12
# Working on: pop.00096.wav Segment 0
# Working on: pop.00096.wav Segment 1
# Working on: pop.00096.wav Segment 2
# Working on: pop.00096.wav Segment 3
# Working on: pop.00096.wav Segment 4
# Working on: pop.00096.wav Segment 5
# Working on: pop.00096.wav Segment 6
# Working on: pop.00096.wav Segment 7
# Working on: pop.00096.wav Segment 8
# Working on: pop.00096.wav Segment 9
# Working on: pop.00096.wav Segment 10
# Working on: pop.00096.wav Segment 11
# Working on: pop.00096.wav Segment 12
# Working on: pop.00097.wav Segment 0
# Working on: pop.00097.wav Segment 1
# Working on: pop.00097.wav Segment 2
# Working on: pop.00097.wav Segment 3
# Working on: pop.00097.wav Segment 4
# Working on: pop.00097.wav Segment 5
# Working on: pop.00097.wav Segment 6
# Working on: pop.00097.wav Segment 7
# Working on: pop.00097.wav Segment 8
# Working on: pop.00097.wav Segment 9
# Working on: pop.00097.wav Segment 10
# Working on: pop.00097.wav Segment 11
# Working on: pop.00097.wav Segment 12
# Working on: pop.00091.wav Segment 0
# Working on: pop.00091.wav Segment 1
# Working on: pop.00091.wav Segment 2
# Working on: pop.00091.wav Segment 3
# Working on: pop.00091.wav Segment 4
# Working on: pop.00091.wav Segment 5
# Working on: pop.00091.wav Segment 6
# Working on: pop.00091.wav Segment 7
# Working on: pop.00091.wav Segment 8
# Working on: pop.00091.wav Segment 9
# Working on: pop.00091.wav Segment 10
# Working on: pop.00091.wav Segment 11
# Working on: pop.00091.wav Segment 12
# Working on: pop.00090.wav Segment 0
# Working on: pop.00090.wav Segment 1
# Working on: pop.00090.wav Segment 2
# Working on: pop.00090.wav Segment 3
# Working on: pop.00090.wav Segment 4
# Working on: pop.00090.wav Segment 5
# Working on: pop.00090.wav Segment 6
# Working on: pop.00090.wav Segment 7
# Working on: pop.00090.wav Segment 8
# Working on: pop.00090.wav Segment 9
# Working on: pop.00090.wav Segment 10
# Working on: pop.00090.wav Segment 11
# Working on: pop.00090.wav Segment 12
# Working on: pop.00095.wav Segment 0
# Working on: pop.00095.wav Segment 1
# Working on: pop.00095.wav Segment 2
# Working on: pop.00095.wav Segment 3
# Working on: pop.00095.wav Segment 4
# Working on: pop.00095.wav Segment 5
# Working on: pop.00095.wav Segment 6
# Working on: pop.00095.wav Segment 7
# Working on: pop.00095.wav Segment 8
# Working on: pop.00095.wav Segment 9
# Working on: pop.00095.wav Segment 10
# Working on: pop.00095.wav Segment 11
# Working on: pop.00095.wav Segment 12
# Working on: pop.00093.wav Segment 0
# Working on: pop.00093.wav Segment 1
# Working on: pop.00093.wav Segment 2
# Working on: pop.00093.wav Segment 3
# Working on: pop.00093.wav Segment 4
# Working on: pop.00093.wav Segment 5
# Working on: pop.00093.wav Segment 6
# Working on: pop.00093.wav Segment 7
# Working on: pop.00093.wav Segment 8
# Working on: pop.00093.wav Segment 9
# Working on: pop.00093.wav Segment 10
# Working on: pop.00093.wav Segment 11
# Working on: pop.00093.wav Segment 12
# Working on: pop.00098.wav Segment 0
# Working on: pop.00098.wav Segment 1
# Working on: pop.00098.wav Segment 2
# Working on: pop.00098.wav Segment 3
# Working on: pop.00098.wav Segment 4
# Working on: pop.00098.wav Segment 5
# Working on: pop.00098.wav Segment 6
# Working on: pop.00098.wav Segment 7
# Working on: pop.00098.wav Segment 8
# Working on: pop.00098.wav Segment 9
# Working on: pop.00098.wav Segment 10
# Working on: pop.00098.wav Segment 11
# Working on: pop.00098.wav Segment 12
# Working on: pop.00094.wav Segment 0
# Working on: pop.00094.wav Segment 1
# Working on: pop.00094.wav Segment 2
# Working on: pop.00094.wav Segment 3
# Working on: pop.00094.wav Segment 4
# Working on: pop.00094.wav Segment 5
# Working on: pop.00094.wav Segment 6
# Working on: pop.00094.wav Segment 7
# Working on: pop.00094.wav Segment 8
# Working on: pop.00094.wav Segment 9
# Working on: pop.00094.wav Segment 10
# Working on: pop.00094.wav Segment 11
# Working on: pop.00094.wav Segment 12
# Working on: pop.00099.wav Segment 0
# Working on: pop.00099.wav Segment 1
# Working on: pop.00099.wav Segment 2
# Working on: pop.00099.wav Segment 3
# Working on: pop.00099.wav Segment 4
# Working on: pop.00099.wav Segment 5
# Working on: pop.00099.wav Segment 6
# Working on: pop.00099.wav Segment 7
# Working on: pop.00099.wav Segment 8
# Working on: pop.00099.wav Segment 9
# Working on: pop.00099.wav Segment 10
# Working on: pop.00099.wav Segment 11
# Working on: pop.00099.wav Segment 12
# Working on: country.00001.wav Segment 0
# Working on: country.00001.wav Segment 1
# Working on: country.00001.wav Segment 2
# Working on: country.00001.wav Segment 3
# Working on: country.00001.wav Segment 4
# Working on: country.00001.wav Segment 5
# Working on: country.00001.wav Segment 6
# Working on: country.00001.wav Segment 7
# Working on: country.00001.wav Segment 8
# Working on: country.00001.wav Segment 9
# Working on: country.00001.wav Segment 10
# Working on: country.00001.wav Segment 11
# Working on: country.00001.wav Segment 12
# Working on: country.00000.wav Segment 0
# Working on: country.00000.wav Segment 1
# Working on: country.00000.wav Segment 2
# Working on: country.00000.wav Segment 3
# Working on: country.00000.wav Segment 4
# Working on: country.00000.wav Segment 5
# Working on: country.00000.wav Segment 6
# Working on: country.00000.wav Segment 7
# Working on: country.00000.wav Segment 8
# Working on: country.00000.wav Segment 9
# Working on: country.00000.wav Segment 10
# Working on: country.00000.wav Segment 11
# Working on: country.00000.wav Segment 12
# Working on: country.00003.wav Segment 0
# Working on: country.00003.wav Segment 1
# Working on: country.00003.wav Segment 2
# Working on: country.00003.wav Segment 3
# Working on: country.00003.wav Segment 4
# Working on: country.00003.wav Segment 5
# Working on: country.00003.wav Segment 6
# Working on: country.00003.wav Segment 7
# Working on: country.00003.wav Segment 8
# Working on: country.00003.wav Segment 9
# Working on: country.00003.wav Segment 10
# Working on: country.00003.wav Segment 11
# Working on: country.00003.wav Segment 12
# Working on: country.00011.wav Segment 0
# Working on: country.00011.wav Segment 1
# Working on: country.00011.wav Segment 2
# Working on: country.00011.wav Segment 3
# Working on: country.00011.wav Segment 4
# Working on: country.00011.wav Segment 5
# Working on: country.00011.wav Segment 6
# Working on: country.00011.wav Segment 7
# Working on: country.00011.wav Segment 8
# Working on: country.00011.wav Segment 9
# Working on: country.00011.wav Segment 10
# Working on: country.00011.wav Segment 11
# Working on: country.00011.wav Segment 12
# Working on: country.00013.wav Segment 0
# Working on: country.00013.wav Segment 1
# Working on: country.00013.wav Segment 2
# Working on: country.00013.wav Segment 3
# Working on: country.00013.wav Segment 4
# Working on: country.00013.wav Segment 5
# Working on: country.00013.wav Segment 6
# Working on: country.00013.wav Segment 7
# Working on: country.00013.wav Segment 8
# Working on: country.00013.wav Segment 9
# Working on: country.00013.wav Segment 10
# Working on: country.00013.wav Segment 11
# Working on: country.00013.wav Segment 12
# Working on: country.00012.wav Segment 0
# Working on: country.00012.wav Segment 1
# Working on: country.00012.wav Segment 2
# Working on: country.00012.wav Segment 3
# Working on: country.00012.wav Segment 4
# Working on: country.00012.wav Segment 5
# Working on: country.00012.wav Segment 6
# Working on: country.00012.wav Segment 7
# Working on: country.00012.wav Segment 8
# Working on: country.00012.wav Segment 9
# Working on: country.00012.wav Segment 10
# Working on: country.00012.wav Segment 11
# Working on: country.00012.wav Segment 12
# Working on: country.00004.wav Segment 0
# Working on: country.00004.wav Segment 1
# Working on: country.00004.wav Segment 2
# Working on: country.00004.wav Segment 3
# Working on: country.00004.wav Segment 4
# Working on: country.00004.wav Segment 5
# Working on: country.00004.wav Segment 6
# Working on: country.00004.wav Segment 7
# Working on: country.00004.wav Segment 8
# Working on: country.00004.wav Segment 9
# Working on: country.00004.wav Segment 10
# Working on: country.00004.wav Segment 11
# Working on: country.00004.wav Segment 12
# Working on: country.00006.wav Segment 0
# Working on: country.00006.wav Segment 1
# Working on: country.00006.wav Segment 2
# Working on: country.00006.wav Segment 3
# Working on: country.00006.wav Segment 4
# Working on: country.00006.wav Segment 5
# Working on: country.00006.wav Segment 6
# Working on: country.00006.wav Segment 7
# Working on: country.00006.wav Segment 8
# Working on: country.00006.wav Segment 9
# Working on: country.00006.wav Segment 10
# Working on: country.00006.wav Segment 11
# Working on: country.00006.wav Segment 12
# Working on: country.00008.wav Segment 0
# Working on: country.00008.wav Segment 1
# Working on: country.00008.wav Segment 2
# Working on: country.00008.wav Segment 3
# Working on: country.00008.wav Segment 4
# Working on: country.00008.wav Segment 5
# Working on: country.00008.wav Segment 6
# Working on: country.00008.wav Segment 7
# Working on: country.00008.wav Segment 8
# Working on: country.00008.wav Segment 9
# Working on: country.00008.wav Segment 10
# Working on: country.00008.wav Segment 11
# Working on: country.00008.wav Segment 12
# Working on: country.00009.wav Segment 0
# Working on: country.00009.wav Segment 1
# Working on: country.00009.wav Segment 2
# Working on: country.00009.wav Segment 3
# Working on: country.00009.wav Segment 4
# Working on: country.00009.wav Segment 5
# Working on: country.00009.wav Segment 6
# Working on: country.00009.wav Segment 7
# Working on: country.00009.wav Segment 8
# Working on: country.00009.wav Segment 9
# Working on: country.00009.wav Segment 10
# Working on: country.00009.wav Segment 11
# Working on: country.00009.wav Segment 12
# Working on: country.00002.wav Segment 0
# Working on: country.00002.wav Segment 1
# Working on: country.00002.wav Segment 2
# Working on: country.00002.wav Segment 3
# Working on: country.00002.wav Segment 4
# Working on: country.00002.wav Segment 5
# Working on: country.00002.wav Segment 6
# Working on: country.00002.wav Segment 7
# Working on: country.00002.wav Segment 8
# Working on: country.00002.wav Segment 9
# Working on: country.00002.wav Segment 10
# Working on: country.00002.wav Segment 11
# Working on: country.00002.wav Segment 12
# Working on: country.00005.wav Segment 0
# Working on: country.00005.wav Segment 1
# Working on: country.00005.wav Segment 2
# Working on: country.00005.wav Segment 3
# Working on: country.00005.wav Segment 4
# Working on: country.00005.wav Segment 5
# Working on: country.00005.wav Segment 6
# Working on: country.00005.wav Segment 7
# Working on: country.00005.wav Segment 8
# Working on: country.00005.wav Segment 9
# Working on: country.00005.wav Segment 10
# Working on: country.00005.wav Segment 11
# Working on: country.00005.wav Segment 12
# Working on: country.00014.wav Segment 0
# Working on: country.00014.wav Segment 1
# Working on: country.00014.wav Segment 2
# Working on: country.00014.wav Segment 3
# Working on: country.00014.wav Segment 4
# Working on: country.00014.wav Segment 5
# Working on: country.00014.wav Segment 6
# Working on: country.00014.wav Segment 7
# Working on: country.00014.wav Segment 8
# Working on: country.00014.wav Segment 9
# Working on: country.00014.wav Segment 10
# Working on: country.00014.wav Segment 11
# Working on: country.00014.wav Segment 12
# Working on: country.00010.wav Segment 0
# Working on: country.00010.wav Segment 1
# Working on: country.00010.wav Segment 2
# Working on: country.00010.wav Segment 3
# Working on: country.00010.wav Segment 4
# Working on: country.00010.wav Segment 5
# Working on: country.00010.wav Segment 6
# Working on: country.00010.wav Segment 7
# Working on: country.00010.wav Segment 8
# Working on: country.00010.wav Segment 9
# Working on: country.00010.wav Segment 10
# Working on: country.00010.wav Segment 11
# Working on: country.00010.wav Segment 12
# Working on: country.00007.wav Segment 0
# Working on: country.00007.wav Segment 1
# Working on: country.00007.wav Segment 2
# Working on: country.00007.wav Segment 3
# Working on: country.00007.wav Segment 4
# Working on: country.00007.wav Segment 5
# Working on: country.00007.wav Segment 6
# Working on: country.00007.wav Segment 7
# Working on: country.00007.wav Segment 8
# Working on: country.00007.wav Segment 9
# Working on: country.00007.wav Segment 10
# Working on: country.00007.wav Segment 11
# Working on: country.00007.wav Segment 12
# Working on: country.00015.wav Segment 0
# Working on: country.00015.wav Segment 1
# Working on: country.00015.wav Segment 2
# Working on: country.00015.wav Segment 3
# Working on: country.00015.wav Segment 4
# Working on: country.00015.wav Segment 5
# ...
# Working on: reggae.00059.wav Segment 9
# Working on: reggae.00059.wav Segment 10
# Working on: reggae.00059.wav Segment 11
# Working on: reggae.00059.wav Segment 12
# Working on: reggae.00078.wav Segment 0
# Working on: reggae.00078.wav Segment 1
# Working on: reggae.00078.wav Segment 2
# Working on: reggae.00078.wav Segment 3
# Working on: reggae.00084.wav Segment 12
# Working on: reggae.00095.wav Segment 0
# Working on: reggae.00095.wav Segment 1
# Working on: reggae.00095.wav Segment 2
# Working on: reggae.00095.wav Segment 3
# Working on: reggae.00095.wav Segment 4
# Working on: reggae.00095.wav Segment 5
# Working on: reggae.00095.wav Segment 6
# Working on: reggae.00095.wav Segment 7
# Working on: reggae.00095.wav Segment 8
# Working on: reggae.00095.wav Segment 9
# Working on: reggae.00095.wav Segment 10
# Working on: reggae.00095.wav Segment 11
# Working on: reggae.00095.wav Segment 12
# Working on: reggae.00094.wav Segment 0
# Working on: reggae.00094.wav Segment 1
# Working on: reggae.00094.wav Segment 2
# Working on: reggae.00094.wav Segment 3
# Working on: reggae.00094.wav Segment 4
# Working on: reggae.00094.wav Segment 5
# Working on: reggae.00094.wav Segment 6
# Working on: reggae.00094.wav Segment 7
# Working on: reggae.00094.wav Segment 8
# Working on: reggae.00094.wav Segment 9
# Working on: reggae.00094.wav Segment 10
# Working on: reggae.00094.wav Segment 11
# Working on: reggae.00094.wav Segment 12
# Working on: reggae.00092.wav Segment 0
# Working on: reggae.00092.wav Segment 1
# Working on: reggae.00092.wav Segment 2
# Working on: reggae.00092.wav Segment 3
# Working on: reggae.00092.wav Segment 4
# Working on: reggae.00092.wav Segment 5
# Working on: reggae.00092.wav Segment 6
# Working on: reggae.00092.wav Segment 7
# Working on: reggae.00092.wav Segment 8
# Working on: reggae.00092.wav Segment 9
# Working on: reggae.00092.wav Segment 10
# Working on: reggae.00092.wav Segment 11
# Working on: reggae.00092.wav Segment 12
# Working on: reggae.00091.wav Segment 0
# Working on: reggae.00091.wav Segment 1
# Working on: reggae.00091.wav Segment 2
# Working on: reggae.00091.wav Segment 3
# Working on: reggae.00091.wav Segment 4
# Working on: reggae.00091.wav Segment 5
# Working on: reggae.00091.wav Segment 6
# Working on: reggae.00091.wav Segment 7
# Working on: reggae.00091.wav Segment 8
# Working on: reggae.00091.wav Segment 9
# Working on: reggae.00091.wav Segment 10
# Working on: reggae.00091.wav Segment 11
# Working on: reggae.00091.wav Segment 12
# Working on: reggae.00083.wav Segment 0
# Working on: reggae.00083.wav Segment 1
# Working on: reggae.00083.wav Segment 2
# Working on: reggae.00083.wav Segment 3
# Working on: reggae.00083.wav Segment 4
# Working on: reggae.00083.wav Segment 5
# Working on: reggae.00083.wav Segment 6
# Working on: reggae.00083.wav Segment 7
# Working on: reggae.00083.wav Segment 8
# Working on: reggae.00083.wav Segment 9
# Working on: reggae.00083.wav Segment 10
# Working on: reggae.00083.wav Segment 11
# Working on: reggae.00083.wav Segment 12
# Working on: reggae.00082.wav Segment 0
# Working on: reggae.00082.wav Segment 1
# Working on: reggae.00082.wav Segment 2
# Working on: reggae.00082.wav Segment 3
# Working on: reggae.00082.wav Segment 4
# Working on: reggae.00082.wav Segment 5
# Working on: reggae.00082.wav Segment 6
# Working on: reggae.00082.wav Segment 7
# Working on: reggae.00082.wav Segment 8
# Working on: reggae.00082.wav Segment 9
# Working on: reggae.00099.wav Segment 8
# Working on: reggae.00099.wav Segment 9
# Working on: reggae.00099.wav Segment 10
# Working on: reggae.00099.wav Segment 11
# Working on: reggae.00099.wav Segment 12
# Working on: reggae.00097.wav Segment 0
# Working on: reggae.00097.wav Segment 1
# Working on: reggae.00097.wav Segment 2
# Working on: reggae.00097.wav Segment 3
# Working on: reggae.00097.wav Segment 4
# Working on: reggae.00097.wav Segment 5
# Working on: reggae.00097.wav Segment 6
# Working on: reggae.00097.wav Segment 7
# Working on: reggae.00097.wav Segment 8
# Working on: reggae.00097.wav Segment 9
# Working on: reggae.00097.wav Segment 10
# Working on: reggae.00097.wav Segment 11
# Working on: reggae.00097.wav Segment 12

# %% [markdown]
# Save the X and y numpy arrays as .npy files for convenience:

# %%
np.save("mfcc_y_values", y)
np.save("mfcc_values", X)

# %% [markdown]
# Load .npy files to numpy arrays:

# %%
loadedX = np.load('mfcc_values.npy')
loadedY = np.load('mfcc_y_values.npy')

# %% [markdown]
# Now all the MFCC arrays are stored in loadedX:
#
#
#
# 1.   First dimension is the number of mfcc images.
# 2.   Second dimension is the length of mfcc vector.
# 3.   Third dimension is the number of mfcc variables.

# %%
loadedX.shape
# Out:
# (12998, 100, 20)

# %% [markdown]
# Their corresponding classes are stored in loadedY:
# The size of this array is the number of mfcc images.

# %%
loadedY.shape
# Out:
# (12998,)

# %% [markdown]
# ---
# Split validation, train and test set as:
#
#
#
# 1.   60 % Train set
# 2.   20 % Test set
# 3.   20 % Validation set

# %%
from sklearn.preprocessing import scale

# %%
# Split dataset into train test and validation set.
X_train, X_test, y_train, y_test = train_test_split(loadedX, loadedY, test_size=0.2)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.25)

# %%
# Add one axis representing the grayscale channel.
X_train = X_train[..., np.newaxis]
X_test = X_test[..., np.newaxis]
X_validation = X_validation[..., np.newaxis]

# %%
X_train.shape
# Out:
# (7798, 100, 20, 1)

# %% [markdown]
# Let's inspect one image, representing the mfcc values in one segment from the train set:

# %%
X_trainExample = X_train[0,:, :, 0]
X_trainExample = X_trainExample.T

plt.figure(figsize=(10,5))
librosa.display.specshow(X_trainExample, sr=sampleRate, hop_length=hopLength)
plt.xlabel("Time")
plt.ylabel("MFCC")
plt.title("Example from train set:")
# Out:
# Text(0.5, 1.0, 'Example from train set:')

# %%
model = models.Sequential()

#Layer 1
model.add(Convolution2D(32, (3, 3), activation='relu', input_shape=(X_train.shape[1], X_train.shape[2], 1)))
model.add(MaxPooling2D(pool_size=(2, 2), strides = (2,2) , padding = 'same'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dropout(.4))

#Layer 2
model.add(Convolution2D(64, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(3,3), strides = (2,2) , padding = 'same'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dropout(.4))

#Layer 3
model.add(Convolution2D(128, (2, 2), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides = (2,2) , padding = 'same'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dropout(.5))

model.add(Flatten())
model.add(keras.layers.Dropout(.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 98, 18, 32)        320
#
#  max_pooling2d_15 (MaxPoolin  (None, 49, 9, 32)        0
#  g2D)
#
#  batch_normalization_15 (Bat  (None, 49, 9, 32)        128
#  chNormalization)
#
#  dropout_18 (Dropout)        (None, 49, 9, 32)         0
#
#  conv2d_16 (Conv2D)          (None, 47, 7, 64)         18496
#
#  max_pooling2d_16 (MaxPoolin  (None, 24, 4, 64)        0
#  g2D)
#
#  batch_normalization_16 (Bat  (None, 24, 4, 64)        256
#  chNormalization)
#
#  dropout_19 (Dropout)        (None, 24, 4, 64)         0
#
#  conv2d_17 (Conv2D)          (None, 23, 3, 128)        32896
#
#  max_pooling2d_17 (MaxPoolin  (None, 12, 2, 128)       0
#  g2D)
#
#  batch_normalization_17 (Bat  (None, 12, 2, 128)       512
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 12, 2, 128)        0
#
#  flatten_5 (Flatten)         (None, 3072)              0
#
#  dropout_21 (Dropout)        (None, 3072)              0
#
#  dense_10 (Dense)            (None, 64)                196672
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 249,930
# Trainable params: 249,482
# Non-trainable params: 448
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'] )

history = model.fit(X_train, y_train, epochs=64, 
                    validation_data=(X_validation, y_validation),callbacks= [EarlyStopping(monitor='val_accuracy', patience=15)])
# Out:
# Epoch 1/64
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 244/244 [==============================] - 33s 131ms/step - loss: 1.9044 - accuracy: 0.3448 - val_loss: 1.5134 - val_accuracy: 0.4623
# Epoch 2/64
# 244/244 [==============================] - 31s 127ms/step - loss: 1.4042 - accuracy: 0.4809 - val_loss: 1.7346 - val_accuracy: 0.3873
# Epoch 3/64
# 244/244 [==============================] - 33s 136ms/step - loss: 1.2838 - accuracy: 0.5264 - val_loss: 1.5467 - val_accuracy: 0.4619
# Epoch 4/64
# 244/244 [==============================] - 31s 127ms/step - loss: 1.1901 - accuracy: 0.5609 - val_loss: 1.3304 - val_accuracy: 0.5235
# Epoch 5/64
# 244/244 [==============================] - 31s 128ms/step - loss: 1.1351 - accuracy: 0.5825 - val_loss: 1.4776 - val_accuracy: 0.4973
# Epoch 6/64
# 244/244 [==============================] - 31s 128ms/step - loss: 1.0752 - accuracy: 0.6068 - val_loss: 1.4208 - val_accuracy: 0.5369
# Epoch 7/64
# 244/244 [==============================] - 31s 128ms/step - loss: 1.0425 - accuracy: 0.6293 - val_loss: 1.2663 - val_accuracy: 0.5623
# Epoch 8/64
# 244/244 [==============================] - 37s 152ms/step - loss: 1.0160 - accuracy: 0.6295 - val_loss: 1.1891 - val_accuracy: 0.5977
# Epoch 9/64
# 244/244 [==============================] - 32s 131ms/step - loss: 0.9838 - accuracy: 0.6494 - val_loss: 1.2788 - val_accuracy: 0.5850
# Epoch 10/64
# 244/244 [==============================] - 32s 130ms/step - loss: 0.9444 - accuracy: 0.6620 - val_loss: 1.3392 - val_accuracy: 0.5619
# Epoch 11/64
# 244/244 [==============================] - 32s 130ms/step - loss: 0.9064 - accuracy: 0.6730 - val_loss: 1.1474 - val_accuracy: 0.6158
# Epoch 12/64
# 244/244 [==============================] - 34s 138ms/step - loss: 0.9043 - accuracy: 0.6747 - val_loss: 1.0712 - val_accuracy: 0.6354
# Epoch 13/64
# 244/244 [==============================] - 32s 130ms/step - loss: 0.8796 - accuracy: 0.6892 - val_loss: 1.2903 - val_accuracy: 0.5773
# Epoch 14/64
# 244/244 [==============================] - 31s 128ms/step - loss: 0.8654 - accuracy: 0.6939 - val_loss: 1.0543 - val_accuracy: 0.6404
# Epoch 15/64
# 244/244 [==============================] - 31s 128ms/step - loss: 0
64
# 244/244 [==============================] - 31s 129ms/step - loss: 0.4811 - accuracy: 0.8329 - val_loss: 0.6265 - val_accuracy: 0.7973
# Epoch 62/64
# 244/244 [==============================] - 31s 129ms/step - loss: 0.4951 - accuracy: 0.8229 - val_loss: 0.6487 - val_accuracy: 0.7981
# Epoch 63/64
# 244/244 [==============================] - 31s 128ms/step - loss: 0.4777 - accuracy: 0.8280 - val_loss: 0.6785 - val_accuracy: 0.7908
# Epoch 64/64
# 244/244 [==============================] - 33s 137ms/step - loss: 0.4751 - accuracy: 0.8289 - val_loss: 0.6678 - val_accuracy: 0.7969

# %% [markdown]
# Plot the model:

# %%
# Plot the model's test and train accuracy
plt.plot(history.history["accuracy"], label="Train accuracy")
plt.plot(history.history["val_accuracy"], label="Validation accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.title("Evaluation")
plt.legend(loc="lower right")

plt.show()

# %% [markdown]
# Test acccuracy:

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 82/82 [==============================] - 2s 30ms/step - loss: 0.6855 - accuracy: 0.7831
# Test accuracy: 0.7830769419670105

# %% [markdown]
# Validation Accuracy

# %%
validation_loss, validation_acc = model.evaluate(X_validation, y_validation)
print('Validation accuracy:', validation_acc)
# Out:
# 82/82 [==============================] - 2s 30ms/step - loss: 0.6678 - accuracy: 0.7969
# Validation accuracy: 0.7969231009483337

# %% [markdown]
# Predict a song that's outside the set.
# Pick a segment from a song.

# %%
# Audio files pre-processing

#audio_path = "/content/drive/MyDrive/BossaAntiguaPrediction.mp3"
#audio_path = "/content/drive/MyDrive/Scott_Fields_Santa_on_a_Segway.mp3"
#audio_path = "/content/drive/MyDrive/Bryan_Mathys_Wild_Heart.mp3"
audio_path = "/content/drive/MyDrive/IMLC_Messiah_for_Hire.mp3"

currentAudio,sampleRate = librosa.load(audio_path, sr=sampleRate)
XasList = []

  # Go through one audio file
for i in range(segments):

      # Print which audio file is currently being worked on.
              printMessage = f'Working on: {audio_path.split("/")[4]} Segment {i}'
              print(printMessage)

              # Calculate the start and finish points of segments.
              start = samplePerSeg * i
              finish = start + samplePerSeg

              # Calculate mfcc of audio segment.
              mfcc = librosa.feature.mfcc(currentAudio[start:finish], sampleRate, n_mfcc=numMFCC, n_fft=nFFT, hop_length=hopLength)
              mfcc = mfcc.T

              # Add MFCC to data only if the mfcc vector length are good
              
              if mfcc.shape[0] == mfccPerSeg:
                XasList.append(mfcc.tolist())
          
  # Convert python list to numpy array
X = np.array(XasList)




Xprediction = X[8]
Xprediction = Xprediction[np.newaxis, ..., np.newaxis]
prediction = model.predict(Xprediction)
predicted_index = np.argmax(prediction, axis=1)
print(printMessage)
print("Predicted genre's number:", predicted_index)
# Out:
# /usr/local/lib/python3.8/dist-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 0
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 1
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 2
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 3
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 4
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 5
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 6
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 7
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 8
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 9
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 10
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 11
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 12
# 1/1 [==============================] - 0s 34ms/step
# Working on: IMLC_Messiah_for_Hire.mp3 Segment 12
# Predicted genre's number: [9]

# %% [markdown]
# genreToNum = {
#       "blues":0,
#       "classical":1,
#       "country":2,
#       "disco":3,
#       "hiphop":4,
#       "jazz" :5,
#       "metal" :6,
#       "pop" :7,
#       "reggae" :8,
#       "rock" :9
#   }
